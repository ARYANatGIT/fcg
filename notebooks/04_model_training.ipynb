# %% [markdown]
# # 04 — LightGBM Bust Classification & Probability Calibration
# ### ForecastGuard AI — MoES / NCMRWF (Problem Statement ID: 26079)
# **Scope:** Train baseline Logistic Regression, Random Forest, and LightGBM models using strict temporal splitting with isotonic calibration.
#
# > **Notice:** `SYNTHETIC DEMONSTRATION DATA — NOT REAL WEATHER DATA`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Load synthetic demonstration data
data_path = Path('../data/synthetic/weather_demo.parquet')
if not data_path.exists():
    data_path = Path('data/synthetic/weather_demo.parquet')

df = pd.read_parquet(data_path)
print(f'Loaded {len(df):,} records.')
print(f'Data Source: {df.attrs.get("data_source", "Synthetic")}')
df.head()
